# %%
import requests
import pandas as pd

# %%
url = "https://data.binance.com/api/v3/ticker/24hr"
response = requests.get(url)

# %%
if response.status_code == 200:
  data = response.json()

  df = pd.DataFrame(data)
    
  df.to_csv("binance_data.csv", index=False)

  print(f"Data successfully saved to binance_data.csv")

else:
  print("Data request is unsuccessful")
# Out:
# Data successfully saved to binance_data.csv

# %%
data = pd.read_csv("binance_data.csv")
data.head()
# Out:
#     symbol  priceChange  priceChangePercent  weightedAvgPrice  prevClosePrice  \
# 0   ETHBTC    -0.000570              -0.942          0.060248        0.060500
# 1   LTCBTC    -0.000098              -3.948          0.002431        0.002482
# 2   BNBBTC    -0.000045              -0.564          0.007975        0.007981
# 3   NEOBTC    -0.000004              -1.431          0.000280        0.000280
# 4  QTUMETH     0.000002               0.148          0.001343        0.001355
#
#    lastPrice  lastQty  bidPrice    bidQty  askPrice  ...  openPrice  \
# 0   0.059920   1.3959  0.059910   62.1127  0.059920  ...   0.060490
# 1   0.002384   0.0630  0.002384  287.1510  0.002386  ...   0.002482
# 2   0.007936   0.2290  0.007936   29.3230  0.007937  ...   0.007981
# 3   0.000276   1.1900  0.000275   26.7100  0.000276  ...   0.000280
# 4   0.001356  25.1000  0.001355   90.6000  0.001359  ...   0.001354
#
#    highPrice  lowPrice      volume  quoteVolume       openTime      closeTime  \
# 0   0.060700  0.059897  16668.5467  1004.244008  1695142837049  1695229237049
# 1   0.002491  0.002369  93957.6720   228.418904  1695142833217  1695229233217
# 2   0.008007  0.007927  15538.7720   123.927796  1695142830419  1695229230419
# 3   0.000286  0.000275  12808.1200     3.591518  1695142790076  1695229190076
# 4   0.001361  0.001341    732.8000     0.984139  1695142805285  1695229205285
#
#      firstId     lastId  count
# 0  423146571  423175959  29389
# 1   93544302   93559897  15596
# 2  227211476  227233650  22175
# 3   45517124   45520976   3853
# 4    5402177    5402202     26
#
# [5 rows x 21 columns]
